# %% [markdown]
# # AI-NIDS: Khám Phá Dữ Liệu (EDA) & Trích Chọn Đặc Trưng (Feature Selection)
# **Dự án:** Phát hiện Xâm nhập Mạng Ứng dụng Học máy Thời gian thực (AI-NIDS)
#
# **Bộ dữ liệu:** UNSW-NB15 Dataset (Kaggle: `dhoogla/unswnb15`)
#
# **Đơn vị:** Nhóm 03 - Khóa thực tập Doanh nghiệp DTG 2026
#
# **Phụ trách:** Trần Ngọc Hải, Trần Thị Thu Hiền, Văn Đức Cường

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Nạp dữ liệu mẫu
df = pd.read_csv('../../data/sample_unsw_test.csv')
print('Kích thước tập mẫu:', df.shape)
df.head()
